# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Import Data

# %%
#set path of the raw data
get_raw_data_script_file = os.path.join(os.path.pardir,'src','data','get_raw_data.py')
get_raw_data_script_file =os.path.abspath(get_raw_data_script_file)
get_raw_data_script_path = os.path.join(os.path.pardir,'src','data')
get_raw_data_script_path = os.path.join(os.path.pardir,get_raw_data_script_path,'raw')
if not os.path.exists(get_raw_data_script_path):
    os.makedirs(get_raw_data_script_path)

file_path = os.path.join(get_raw_data_script_path, 'GlobalLandTemperaturesbyCity.csv.zip')

# %%
#read the data with all default parameters
pd.set_option('display.float_format', lambda x: '%.3f' % x)
temps_df = pd.read_csv(file_path)

# %%
temps_df.tail(10)
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 8599202  2012-12-01               4.303                          0.341
# 8599203  2013-01-01               1.479                          0.217
# 8599204  2013-02-01               1.559                          0.304
# 8599205  2013-03-01               2.253                          0.267
# 8599206  2013-04-01               7.710                          0.182
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 8599202  Zwolle  Netherlands   52.24N     5.26E
# 8599203  Zwolle  Netherlands   52.24N     5.26E
# 8599204  Zwolle  Netherlands   52.24N     5.26E
# 8599205  Zwolle  Netherlands   52.24N     5.26E
# 8599206  Zwolle  Netherlands   52.24N     5.26E
# 8599207  Zwolle  Netherlands   52.24N     5.26E
# 8599208  Zwolle  Netherlands   52.24N     5.26E
# 8599209  Zwolle  Netherlands   52.24N     5.26E
# 8599210  Zwolle  Netherlands   52.24N     5.26E
# 8599211  Zwolle  Netherlands   52.24N     5.26E

# %%
type(temps_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Basic Structure

# %%
temps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599212 entries, 0 to 8599211
# Data columns (total 7 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             object
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
# dtypes: float64(2), object(5)
# memory usage: 459.2+ MB

# %%
temps_df.loc[temps_df.Country =='United Kingdom']
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 38481    1743-11-01               8.758                          1.886
# 38482    1743-12-01                 NaN                            NaN
# 38483    1744-01-01                 NaN                            NaN
# 38484    1744-02-01                 NaN                            NaN
# 38485    1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8442481  2013-05-01              10.322                          0.537
# 8442482  2013-06-01              13.804                          0.320
# 8442483  2013-07-01              17.749                          0.446
# 8442484  2013-08-01              16.473                          0.302
# 8442485  2013-09-01                 NaN                            NaN
#
#              City         Country Latitude Longitude
# 38481    Aberdeen  United Kingdom   57.05N     1.48W
# 38482    Aberdeen  United Kingdom   57.05N     1.48W
# 38483    Aberdeen  United Kingdom   57.05N     1.48W
# 38484    Aberdeen  United Kingdom   57.05N     1.48W
# 38485    Aberdeen  United Kingdom   57.05N     1.48W
# ...           ...             ...      ...       ...
# 8442481      York  United Kingdom   53.84N     1.36W
# 8442482      York  United Kingdom   53.84N     1.36W
# 8442483      York  United Kingdom   53.84N     1.36W
# 8442484      York  United Kingdom   53.84N     1.36W
# 8442485      York  United Kingdom   53.84N     1.36W
#
# [220252 rows x 7 columns]

# %% [markdown]
# ## Summary Statistics

# %%
temps_df.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count         8235082.000                    8235082.000
# mean               16.727                          1.029
# std                10.353                          1.130
# min               -42.704                          0.034
# 25%                10.299                          0.337
# 50%                18.831                          0.591
# 75%                25.210                          1.349
# max                39.651                         15.396

# %%
# numerical feature
#centrality measures
print('Mean Temperature : {0:.5}'.format(temps_df.AverageTemperature.mean()),u"\N{DEGREE SIGN}C") # mean\n,
print('Median Temperature : {0:.5}'.format(temps_df.AverageTemperature.median()),u"\N{DEGREE SIGN}C") # median
# Out:
# Mean Temperature : 16.727 °C
# Median Temperature : 18.831 °C

# %%
# dispersion measures
print('Min Temperature : {0:.5}'.format(temps_df.AverageTemperature.min()),u"\N{DEGREE SIGN}C") # minimum\n,
print('Max Temperature : {0:.5}'.format(temps_df.AverageTemperature.max()),u"\N{DEGREE SIGN}C") # maximum\n,
print('Temperature range : {0:.5}'.format(temps_df.AverageTemperature.max()  - temps_df.AverageTemperature.min()),u"\N{DEGREE SIGN}C") # range\n,
print('25 percentile : {0:.5}'.format(temps_df.AverageTemperature.quantile(.25)),u"\N{DEGREE SIGN}C") # 25 percentile\n,
print('50 percentile : {0:.5}'.format(temps_df.AverageTemperature.quantile(.5)),u"\N{DEGREE SIGN}C") # 50 percentile\n,
print('75 percentile : {0:.5}'.format(temps_df.AverageTemperature.quantile(.75)),u"\N{DEGREE SIGN}C") # 75 percentile\n,
print('Variance Temperature : {0:.5}'.format(temps_df.AverageTemperature.var()),u"\N{DEGREE SIGN}C") # variance\n,
print('Standard deviation Temperature : {0:.5}'.format(temps_df.AverageTemperature.std()),u"\N{DEGREE SIGN}C") # standard deviation
# Out:
# Min Temperature : -42.704 °C
# Max Temperature : 39.651 °C
# Temperature range : 82.355 °C
# 25 percentile : 10.299 °C
# 50 percentile : 18.831 °C
# 75 percentile : 25.21 °C
# Variance Temperature : 107.19 °C
# Standard deviation Temperature : 10.353 °C

# %%
#box-whisker plot comparing AverageTemperature of countries
import seaborn as sns

sns.set(rc={'figure.figsize':(11.7,15)})
ukandchina = temps_df[(temps_df['Country'] == 'United Kingdom') | (temps_df['Country'] == 'China') | (temps_df['Country'] == 'Australia') | (temps_df['Country'] == 'United States')]
ax= sns.boxplot(x="Country", y="AverageTemperature", hue="Country", data=ukandchina, flierprops={"marker":"x","markerfacecolor":"grey", "markeredgecolor":"grey"})

# %%
#use .describe(include= 'all') to get stats for all columns including non-numeric ones

temps_df.describe(include = 'all')
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# count      8599212         8235082.000                    8235082.000
# unique        3239                 NaN                            NaN
# top     2012-03-01                 NaN                            NaN
# freq          3510                 NaN                            NaN
# mean           NaN              16.727                          1.029
# std            NaN              10.353                          1.130
# min            NaN             -42.704                          0.034
# 25%            NaN              10.299                          0.337
# 50%            NaN              18.831                          0.591
# 75%            NaN              25.210                          1.349
# max            NaN              39.651                         15.396
#
#                City  Country Latitude Longitude
# count       8599212  8599212  8599212   8599212
# unique         3448      159       73      1227
# top     Springfield    India   36.17N   139.23E
# freq           9545  1014906   425455    129600
# mean            NaN      NaN      NaN       NaN
# std             NaN      NaN      NaN       NaN
# min             NaN      NaN      NaN       NaN
# 25%             NaN      NaN      NaN       NaN
# 50%             NaN      NaN      NaN       NaN
# 75%             NaN      NaN      NaN       NaN
# max             NaN      NaN      NaN       NaN

# %%
#categorical column: counts
temps_df.Country.value_counts()
# Out:
# India               1014906
# China                827802
# United States        687289
# Brazil               475580
# Russia               461234
#                      ...
# Namibia                1881
# Eritrea                1797
# Djibouti               1797
# Oman                   1653
# Papua New Guinea       1581
# Name: Country, Length: 159, dtype: int64

# %%
#categorical column: Proportions
counts = temps_df.Country.value_counts(normalize = True)
counts.multiply(100).round(decimals= 3).astype(str) +" %"
# Out:
# India               11.802 %
# China                9.626 %
# United States        7.992 %
# Brazil               5.531 %
# Russia               5.364 %
#                       ...
# Namibia              0.022 %
# Eritrea              0.021 %
# Djibouti             0.021 %
# Oman                 0.019 %
# Papua New Guinea     0.018 %
# Name: Country, Length: 159, dtype: object

# %%
#visualise counts
temps_df.loc[(temps_df['Country'] == 'United Kingdom') | (temps_df['Country'] == 'China') | (temps_df['Country'] == 'Australia') | (temps_df['Country'] == 'United States')].Country.value_counts().plot(kind='bar', figsize = (12,5), rot = 0, title = 'Count of Values for Each Country', color = 'c');

# %% [markdown]
# ## Distributions

# %%
# use kde to create create density plot 
temps_df.AverageTemperature.plot(kind = 'kde', title = 'Density plot for Average Temperature', color = 'c', figsize = (12,8), xlabel = 'Average temperature');

# %%
print('skewness for Average Temperature : {0:.2f}'.format(temps_df.AverageTemperature.skew()))
# Out:
# skewness for Average Temperature : -0.89

# %%
# take N as +ve values and S as -ve values for latitude

temps_df.Latitude[temps_df.Latitude.str.contains('N')]  = temps_df.Latitude.str.replace('N', '') 
temps_df.Latitude[temps_df.Latitude.str.contains('S')] = "-" + temps_df.Latitude[temps_df.Latitude.str.contains('S')].str.replace('S','')
temps_df.Latitude = temps_df.Latitude.astype(float)
# Out:
# <ipython-input-20-18888b6e81fb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps_df.Latitude[temps_df.Latitude.str.contains('N')]  = temps_df.Latitude.str.replace('N', '')
# <ipython-input-20-18888b6e81fb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps_df.Latitude[temps_df.Latitude.str.contains('S')] = "-" + temps_df.Latitude[temps_df.Latitude.str.contains('S')].str.replace('S','')

# %%
# plot a scatter graph of average temperature against latitude for specific date

temps_df_lat = temps_df[temps_df.dt == '2012-09-01'].groupby('Country').mean() #find mean of all numerical values in df for each country

temps_df_lat.reset_index().plot.scatter(x = 'Latitude', y = 'AverageTemperature', color = 'c', title = 'Average Temperature for 2012-09-01');

# %% [markdown]
# ## Grouping and Aggregations

# %%
# group by and aggregate
temps_df.groupby('Country').agg({'AverageTemperature': 'mean', 'Latitude': max})
# Out:
#              AverageTemperature  Latitude
# Country
# Afghanistan              13.816    36.170
# Albania                  15.526    40.990
# Algeria                  17.763    36.170
# Angola                   21.760    -8.840
# Argentina                16.999   -24.920
# ...                         ...       ...
# Venezuela                25.482    12.050
# Vietnam                  24.847    21.700
# Yemen                    25.768    13.660
# Zambia                   20.938   -12.050
# Zimbabwe                 19.823   -18.480
#
# [159 rows x 2 columns]

# %%
# more complex aggregations

aggregations = {
    'AverageTemperature' : ['mean', 'median', max, min],
    'Latitude' : [max, min, lambda x: max(x)-min(x)]
    
}
aggregations
# Out:
# {'AverageTemperature': ['mean', 'median', <function max>, <function min>],
#  'Latitude': [<function max>, <function min>, <function __main__.<lambda>(x)>]}

# %%
temps_df.groupby('Country').agg(aggregations)
# Out:
#             AverageTemperature                      Latitude          \
#                           mean median    max    min      max     min
# Country
# Afghanistan             13.816 14.165 32.950 -8.192   36.170  31.350
# Albania                 15.526 15.058 27.361  2.831   40.990  40.990
# Algeria                 17.763 16.802 39.651  2.228   36.170  31.350
# Angola                  21.760 21.434 28.085 14.897   -8.840 -15.270
# Argentina               16.999 17.208 29.509 -1.460  -24.920 -45.810
# ...                        ...    ...    ...    ...      ...     ...
# Venezuela               25.482 25.580 31.591 18.391   12.050   7.230
# Vietnam                 24.847 25.985 31.972  9.324   21.700   8.840
# Yemen                   25.768 26.125 31.085 19.926   13.660  13.660
# Zambia                  20.938 21.419 29.392 13.967  -12.050 -18.480
# Zimbabwe                19.823 20.790 25.846 11.794  -18.480 -20.090
#
#
#             <lambda_0>
# Country
# Afghanistan      4.820
# Albania          0.000
# Algeria          4.820
# Angola           6.430
# Argentina       20.890
# ...                ...
# Venezuela        4.820
# Vietnam         12.860
# Yemen            0.000
# Zambia           6.430
# Zimbabwe         1.610
#
# [159 rows x 7 columns]
